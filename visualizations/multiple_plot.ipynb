# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

data=pd.read_csv('../data/system_metrics.csv')

plt.style.use('fivethirtyeight')
dates=data['timestamp']
cpu_usage=data['cpu_percent']
ram=data['ram_percent']
net_usage=data['net_bytes_per_sec']/1048576


import matplotlib.pyplot as plt
import numpy as np

data_log = data.copy()
plt.figure(figsize=(10,5))

plt.plot(data["cpu_percent"], label="CPU")
plt.plot(data["ram_percent"], label="RAM")
plt.plot(data["net_bytes_per_sec"], label="Network")

plt.legend()
plt.title("System Metrics Over Time")
plt.xlabel("Time")
plt.ylabel("Value")

plt.show()
